# %%
import numpy as np
from numpy.linalg import norm

# %% [markdown]
# ## Урок 1. Линейное пространство. Часть 1.

# %% [markdown]
# __1. Исследовать на линейную зависимость:__ $f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}$
#
# Заметим, что  $f_{4}(x) = f_{3}(x) - f_{1}(x) - f_{2}(x)$ , то есть вектор  $f_4(x)$  может быть выражен через линейную комбинацию остальных, из чего можно сделать вывод, что cистема из четырех функций линейно зависима.

# %% [markdown]
# __2. Исследовать на линейную зависимость:__ $f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$
#
# Так как $f_{4}(x) = f_{3}(x) + 2f_{2}(x) + \frac{1}{2}f_{1}(x)$, то можно сделать вывод, что cистема из данных четырех функций также линейно зависима.

# %% [markdown]
# __3. Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$,  $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$__
#
# $x=(2, 3, 5)=(2,0,0)+(0, 3, 0)+(0, 0, 5)=1\cdot(2, 0, 0)+3\cdot(0, 1, 0)+0.5\cdot(0, 0, 10)=b_{2}+3b_{3}+0.5b_{1}$, то есть координатами вектора $x$ в данном базисе являются $0.5$, $1$, $3$.

# %% [markdown]
# __4. Найти координаты вектора__ $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1$, $x$, $x^{2}$;
#
# $3x^{2}-2x+2$ = $\lambda_{1} \cdot 1 + \lambda_{2} \cdot x +\lambda_{3} \cdot x^{2}$
#
# $\lambda_{1} = 2, \lambda_{2} = -2, \lambda_{3} = 3$ $\rightarrow$ координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$ в данном базисе равны: $2$, $-2$, $3$
#
# б) в базисе $x^{2}$, $x-1$, $1$.
#
# $3x^{2}-2x+2 = \lambda_{1} \cdot x^2 + \lambda_{2} \cdot (x-1) + \lambda_{3} \cdot 1$
#
# $ \lambda_{1} = 3; \lambda_{2} = - 2; \lambda_{3} - \lambda_{2} = 2 $
#
# $ \lambda_{1} = 3; \lambda_{2} = -2; \lambda_{3} = 0 $ $\rightarrow$ координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$ в данном базисе равны: $3$, $-2$, $0$

# %% [markdown]
# __5. Установить, является ли линейным подпространством:__
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# Возможны три вида векторов: $(0,0,a), (0,b,c), (d, 0, e)$, где $a,b,c,d,e$ - любые элементы поля.
#
# Подмножество $L$ линейного пространства $V$ является его подпространством тогда и только тогда, когда для любых элементов $u, v\in L$ и любого $\alpha \in \mathbb{R}$ выполняются условия:
#
# $1)\ u+v\in L;$
#
# $2)\ \alpha\cdot u \in L.$
#
# Проверка для случая, когда у первого вектора первая координата равна нулю, а у второго - вторая: $(0,b,c) + (d, 0, e) = (d, b, c+e) \notin L $
#
# Полученные векторы не принадлежат указанному в задании множеству всех векторов, то есть данное множество не является подпространством линейного пространства $\mathbb{R}^{3}$.
#
# б) все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, \ldots, u_{n}\}$.
#
# Результаты операций $\ u+v$ и $\ \alpha\cdot u$ также будут являться линейными комбинациями заданных векторов $\{u_{1}, u_{2}, ..., u_{n}\}$, поэтому все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, ..., u_{n}\}$ будут являться линейным подпространством.

# %% [markdown]
# ## Урок 1. Линейное пространство. Часть 2.

# %% [markdown]
# __1. Найти скалярное произведение векторов__ $x, y \in \mathbb{R}$:
#
# а) $x = (0,-3, 6),~y =(-4, 7, 9);$
#
# $(x, y) = 0 \cdot (-4)+(-3) \cdot 7+6 \cdot 9 = 0 - 21 + 54 = 33$
#
# б) $x = (7, -4, 0, 1),~y = (-3, 1, 11, 2)$
#
# $(x, y) = 7 \cdot (-3) + (-4) \cdot 1 + 0 \cdot 11 + 1 \cdot 2 = -21 -4 + 0+ 2 = -23$

# %% [markdown]
# __2. Найти нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.__
#
# Евклидова норма векторов: $\left\|x\right\| = \sqrt{\sum_{i}|x_{i}|^{2}}.$
#
# $\left\|x\right\| = (4,2,4)=\sqrt{4^{2}+2^{2}+4^{2}}=6$
#
# $\left\|y\right\| (12,3,4)=\sqrt{12^{2}+3^{2}+4^{2}}=13$
#
# $cos\varphi = \frac{(x,y)}{\left \|x\right \|\cdot\left \|y\right \|}$
#
# $cos(\alpha)=\frac{4 \cdot 12+2 \cdot 3+4 \cdot 4}{\sqrt{4^{2}+2^{2}+4^{2}}*\sqrt{12^{2}+3^{2}+4^{2}}}=\frac{70}{6 \cdot 13}=\frac{70}{78}\approx0.8974$
#
# В соответствии с таблицей косинусов углов $\alpha \approx 26°$

# %% [markdown]
# Линейное пространство над полем вещественных чисел называется _евклидовым пространством_, если на нем введено правило, согласно которому каждой упорядоченной паре векторов $x$ и $y$ поставлено в соответствие вещественное число, называемое _скалярным произведением_ и обозначаемое символом $(x, y)$.
#
# При этом указанное правило должно подчиняться четырем аксиомам:<br>
# 1) $(x,y)=(y,x);$<br>
# 2) $(\lambda x, y)=\lambda(x, y);$<br>
# 3) $(x_{1}+x_{2},y)=(x_{1},y)+(x_{2},y);$<br>
# 4) $(x, x)\geq0$, причем $(x,x)=0\Leftrightarrow x=0.$
#
#
# __3. Будет ли линейное пространство евклидовым, если за скалярное произведение принять:__
#
# а) произведение длин векторов;
#
# Нет. Так как: $(x_1+x_2,y)=(x_1,y)+(x_2,y)$;
#
# $|x_1+x_2| \cdot |y| \neq |x_1| \cdot |y| + |x_2| \cdot |y|$
#
# б) утроенное обычное скалярное произведение векторов?
#
# Да, так как правило подчиняется всем аксиомам:
#
# 1) $3(x,y)=3(y,x);$
#
# 2) $3(\lambda x, y)=3\lambda(x, y);$
#
# 3) $3(x_{1}+x_{2},y)=3(x_{1},y)+3(x_{2},y);$
#
# 4) $3(x, x)\geq0$, причем $3(x,x)=0\Leftrightarrow x=0.$

# %% [markdown]
# __4. Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:__
#
# а) $(1,0,0),(0,0,1);$ - не образуют, так как два вектора не могут образовать ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$.
#
# б) $x=(\frac{1}{\sqrt{2}}, - \frac{1}{\sqrt{2}},0),y=(\frac{1}{\sqrt{2}},\frac{1}{\sqrt{2}},0),z=(0,0,1)$
#
# Проверка ортогональности:
#
# $(x,y)=\frac{1}{\sqrt{2}} \cdot \frac{1}{\sqrt{2}} − \frac{1}{\sqrt{2}} \cdot \frac{1}{\sqrt{2}}+0 \cdot 0=0$
#
# $(x,z)=\frac{1}{\sqrt{2}} \cdot 0−\frac{1}{\sqrt{2}} \cdot 0+0 \cdot 1=0$
#
# $(y,z)=\frac{1}{\sqrt{2}} \cdot 0+\frac{1}{\sqrt{2}} \cdot 0+0 \cdot 1=0$
#
# Соответственно, данные векторы образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$
#
# в) $(\frac{1}{2}, -\frac{1}{2}, 0), (0, \frac{1}{2}, \frac{1}{2}), (0,0,1);$
#
# Проверка ортогональности:
#
# $(x,y)=\frac{1}{2} \cdot 0-\frac{1}{2} \cdot \frac{1}{2}+0 \cdot \frac{1}{2}=-\frac{1}{4}\neq0 \rightarrow $ данные векторы не образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$
#
# г) $(1,0,0),(0,1,0),(0,0,1)$ - образуют, так как
#
# $(x,y)=1 \cdot 0+0 \cdot 1+0 \cdot 0=0$
#
# $(x,z)=1 \cdot 0+0 \cdot 0+0 \cdot 1=0$
#
# $(y,z)=0 \cdot 0+1 \cdot 0+0 \cdot 1=0$
